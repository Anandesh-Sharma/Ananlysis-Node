# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("Downloads/New Data.csv")

# %%
df.head()

# %%
a=[]
for j in range(len(df.columns)):
  if j<21:
    a.append(df.columns[j])
  else:
    indices = [i for i, x in enumerate(df.columns[j]) if x == "\'"]
    word=''
    for k in range(indices[2]+1,indices[3]):
      word+=df.columns[j][k]
    a.append(word)

# %%
a

# %%
df2=pd.read_csv("/content/drive/My Drive/Garvit/Hard Code/ANVIT- NEW DATA.xlsx - 800+.csv")

# %%
df2.head(20)

# %%
df['abc']=0

# %%
df.head()

# %%
df['cibil_age_of_oldest_trade'][0]

# %%
df_n=pd.read_csv("/content/drive/My Drive/Garvit/Hard Code/New Data.csv")
df_n.head()

# %%
k=df_n.columns
#print(k)
j=[]
j.extend(k[:4])
j.extend([k[-1]])
j.extend(k[4:-1])

# %%
df_n = df_n[j]

# %%
df_n.columns

# %%
a=[]
for j in range(len(df_n.columns)):
  if j<22:
    a.append(df_n.columns[j])
  else:
    indices = [i for i, x in enumerate(df_n.columns[j]) if x == "\'"]
    word=''
    for k in range(indices[2]+1,indices[3]):
      word+=df_n.columns[j][k]
    a.append(word)

# %%
df_n.columns=a

# %%
df_n.drop_duplicates(inplace=True)

# %%
k=['cust_id', 'Age', 'profession', 'education','cibil_cust_past30_days', 'gender', 'income_source','month_exp', 'marital_status', 'reference_name', 'Name', 'email',
   'phone', 'registration date', 'CreditScore','cibil_age_of_oldest_trade', 'cibil_number_of_open_trades',
   'Severe_status', 'Number_of_Accounts', 'Total_sanction_amount','Total_Past_Due', 'Single_Highest_Credit','Prime Minister Jaan Dhan Yojana - Overdraft','Personal Loan',
   'Overdraft','Other','Kisan Credit Card','Gold Loan','Consumer Loan','Business Loan - Unsecured','Business Loan - Priority Sector- Agriculture','Business Loan']

# %%
df_n.columns

# %%
df_test=df_n.drop(columns=k)
all_columns_loan=df_test.sum(axis=1)
a=[]
some_columns_loan=df_test[a]
selected=some_columns_loan.sum(axis=1)
all_columns_loan = all_columns_loan - selected

# %% [markdown]
# # Hard Code 4th Anvit

# %%
df_n=pd.read_csv("/content/drive/My Drive/Garvit/Hard Code/RAW DATA SUPER DATA.xlsx - New Data (2).csv")
df_n.head()

# %%
df_n.drop(columns=['Unnamed: 60'],inplace=True)

# %%
k=df_n.columns
#print(k)
j=[]
j.extend(k[:4])
j.extend([k[-1]])
j.extend(k[4:-1])

# %%
df_n = df_n[j]

# %%
a=[]
for j in range(len(df_n.columns)):
  if j<22:
    a.append(df_n.columns[j])
  else:
    indices = [i for i, x in enumerate(df_n.columns[j]) if x == "\'"]
    word=''
    for k in range(indices[2]+1,indices[3]):
      word+=df_n.columns[j][k]
    a.append(word)

# %%
df_n.columns=a

# %%
k=['Auto Loan',
 'Corporate Credit Card',
 'Education Loan',
 'Housing Loan',
 'Secured Credit Card',
 'Used Car Loan']

# %%
#credit_card_count = ['Secured Credit Card','Credit Card','Corporate Credit Card']
#Two_wheeler_count = ['Two-wheeler Loan']
profession_not_3k=['Auto Driver/Driver','Delivery Agent','Tailor','Laborer/Worker']
confirmed=[]
for index, row in df_n.iterrows():
  if row['profession'] not in profession_not_3k:
    if 700>row['CreditScore']>550:
      if row['cibil_age_of_oldest_trade']>23:
        if row['Severe_status'] in ['01+','Non-Delnqt']:
          if row['cibil_cust_past30_days']<3:
            if row[k].sum()>0:
              '''credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
              ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
              if ratio<=0.4:'''
              confirmed.append((row['cust_id'],2000))

# %%
len(confirmed)

# %%
confirmed

# %%
r1500=0
r2000=0
r3000=0
r4000=0
for i in confirmed:
  if i[1]==1500:
    r1500+=1
  elif i[1]==2000:
    r2000+=1
  elif i[1]==3000:
    r3000+=1
  elif i[1]==4000:
    r4000+=1

# %%
r1500,r2000,r3000,r4000

# %% [markdown]
# # Hard Code 3rd Dheeraj

# %%
df_n=pd.read_csv("/content/drive/My Drive/Garvit/Hard Code/New Data.csv")
df_n.head()

# %%
df_n.drop(columns=['Unnamed: 60'],inplace=True)

# %%
k=df_n.columns
#print(k)
j=[]
j.extend(k[:4])
j.extend([k[-1]])
j.extend(k[4:-1])

# %%
df_n = df_n[j]

# %%
a=[]
for j in range(len(df_n.columns)):
  if j<22:
    a.append(df_n.columns[j])
  else:
    indices = [i for i, x in enumerate(df_n.columns[j]) if x == "\'"]
    word=''
    for k in range(indices[2]+1,indices[3]):
      word+=df_n.columns[j][k]
    a.append(word)

# %%
df_n.columns=a

# %%
k=['cust_id', 'Age', 'profession', 'education','cibil_cust_past30_days', 'gender', 'income_source','month_exp', 'marital_status', 'reference_name', 'Name', 'email',
   'phone', 'registration date', 'CreditScore','cibil_age_of_oldest_trade', 'cibil_number_of_open_trades',
   'Severe_status', 'Number_of_Accounts', 'Total_sanction_amount','Total_Past_Due', 'Single_Highest_Credit','Prime Minister Jaan Dhan Yojana - Overdraft','Personal Loan',
   'Overdraft','Other','Kisan Credit Card','Gold Loan','Consumer Loan','Business Loan - Unsecured','Business Loan - Priority Sector- Agriculture','Business Loan']

# %%
df_n.drop_duplicates(keep='first',inplace=True)

# %%
d=[]
for i,row in df_n.iterrows():
  if(row['CreditScore']<550):
    d.append(False)
  else:
    d.append(True)

# %%
df_n=df_n[d]

# %%
df_n.shape

# %%
#credit_card_count = ['Secured Credit Card','Credit Card','Corporate Credit Card']
Two_wheeler_count = ['Two-wheeler Loan']
Loan_769_above_24_above=['Auto Loan','Education Loan','Property Loan','Housing Loan', 'Secured Credit Card', 'Loan Against Bank Deposits']
profession_not_3k=['Auto Driver/Driver','Delivery Agent','Tailor','Laborer/Worker']
confirmed=[]
for index, row in df_n.iterrows():
  if row['CreditScore']>799:
    if row['cibil_age_of_oldest_trade']>35:
      if row['Severe_status'] in ['01+','Non-Delnqt']:
        if row['cibil_cust_past30_days']<2:
          if row.drop(k).sum()>0:
            '''credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
            ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
            if ratio<=0.4:'''
            confirmed.append((row['cust_id'],4000))

    elif row['cibil_age_of_oldest_trade']>24:
      if row['Severe_status'] in ['01+','Non-Delnqt','Std']:
        if row['cibil_cust_past30_days']<3:
          if row.drop(k).sum()>0:
            '''credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
            ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
            if ratio<=0.4:'''
            confirmed.append((row['cust_id'],3000))

    elif row['cibil_age_of_oldest_trade']>11:
      if row['Severe_status'] in ['01+','Non-Delnqt','Std','30+']:
        if row['cibil_cust_past30_days']<3:
          if row.drop(k).sum()>0:
            '''credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
            ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
            if ratio<=0.4:'''
            confirmed.append((row['cust_id'],3000))

  elif row['CreditScore']>779:
    if row['cibil_age_of_oldest_trade']>59:
      if row['Severe_status'] in ['01+','Non-Delnqt','Std']:
        if row['cibil_cust_past30_days']<2:
          if row.drop(k).sum()>0:
            '''credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
            ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
            if ratio<=0.4:'''
            confirmed.append((row['cust_id'],4000))
    
    elif row['cibil_age_of_oldest_trade']>35:
      if row['Severe_status'] in ['01+','Non-Delnqt']:
        if row['cibil_cust_past30_days']<2:
          if row.drop(k).sum()>0:
            '''credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
            ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
            if ratio<=0.4:'''
            confirmed.append((row['cust_id'],3000))

    elif row['cibil_age_of_oldest_trade']>24:
      if row['Severe_status'] in ['01+','Non-Delnqt','Std']:
        if row['cibil_cust_past30_days']<2:
          if row[Loan_769_above_24_above].sum()>0:
            '''credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
            ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
            if ratio<=0.4:'''
            confirmed.append((row['cust_id'],3000))
  
  elif row['CreditScore']>769:
    if row['cibil_age_of_oldest_trade']>35:
      if row['Severe_status'] in ['01+','Non-Delnqt','Std']:
        if row['cibil_cust_past30_days']<3:
          if row.drop(k).drop(Two_wheeler_count).sum()>0:
            '''credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
            ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
            if ratio<=0.4:'''
            confirmed.append((row['cust_id'],3000))
    
    elif row['cibil_age_of_oldest_trade']>24:
      if row['Severe_status'] in ['01+','Non-Delnqt','Std']:
        if row['cibil_cust_past30_days']<2:
          if row.drop(k).drop(Two_wheeler_count).sum()>0:
            '''credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
            ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
            if ratio<=0.4:'''
            confirmed.append((row['cust_id'],3000))

    elif row['cibil_age_of_oldest_trade']>11:
      if row['profession'] not in profession_not_3k:
        if row['Severe_status'] in ['01+','Non-Delnqt','Std']:
          if row['cibil_cust_past30_days']<2:
            if row.drop(k).drop(Two_wheeler_count).sum()>0:
              '''credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
              ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
              if ratio<=0.4:'''
              confirmed.append((row['cust_id'],3000))

# %%
confirmed

# %%
java=confirmed

# %%
df_n.shape

# %%
len(confirmed)

# %%
r1500=0
r2000=0
r3000=0
r4000=0
for i in confirmed:
  if i[1]==1500:
    r1500+=1
  elif i[1]==2000:
    r2000+=1
  elif i[1]==3000:
    r3000+=1
  elif i[1]==4000:
    r4000+=1

# %%
r1500,r2000,r3000,r4000

# %% [markdown]
# # Hard Code 3rd Anvit

# %%
df_n=pd.read_csv("/content/drive/My Drive/Garvit/Hard Code/New Data.csv")
df_n.head()

# %%
k=df_n.columns
#print(k)
j=[]
j.extend(k[:4])
j.extend([k[-1]])
j.extend(k[4:-1])

# %%
df_n = df_n[j]

# %%
a=[]
for j in range(len(df_n.columns)):
  if j<22:
    a.append(df_n.columns[j])
  else:
    indices = [i for i, x in enumerate(df_n.columns[j]) if x == "\'"]
    word=''
    for k in range(indices[2]+1,indices[3]):
      word+=df_n.columns[j][k]
    a.append(word)

# %%
df_n.columns=a

# %%
k=['Auto Loan',
 'Business Loan - Priority Sector- Others',
 'Business Loan - Priority Sector- Small Business',
 'Business Loan - Secured',
 'Business Loan Against Bank Deposits',
 'Business Non-Funded Credit Facility',
 'Business Non-Funded Credit Facility - Priority Sector - Small Business',
 'Commercial Vehicle Loan',
 'Corporate Credit Card',
 'Education Loan',
 'Housing Loan',
 'Loan Against Bank Deposits',
 'Loan against Shares/Securities',
 'Loan to Professional',
 'Property Loan',
 'Secured Credit Card',
 'Tractor Loan',
 'Used Car Loan']

# %%
#credit_card_count = ['Secured Credit Card','Credit Card','Corporate Credit Card']
#Two_wheeler_count = ['Two-wheeler Loan']
profession_not_3k=['Auto Driver/Driver','Delivery Agent','Tailor','Laborer/Worker']
confirmed=[]
for index, row in df_n.iterrows():
  if row['profession'] not in profession_not_3k:
    if row['CreditScore']>699:
      if row['cibil_age_of_oldest_trade']>11:
        if row['Severe_status'] in ['01+','Non-Delnqt','Std','30+','60+']:
          if row['cibil_cust_past30_days']<3:
            if row[k].sum()>0:
              '''credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
              ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
              if ratio<=0.4:'''
              confirmed.append((row['cust_id'],3000))

# %%
confirmed

# %%
df_n.shape

# %%
len(confirmed)

# %%
r1500=0
r2000=0
r3000=0
r4000=0
for i in confirmed:
  if i[1]==1500:
    r1500+=1
  elif i[1]==2000:
    r2000+=1
  elif i[1]==3000:
    r3000+=1
  elif i[1]==4000:
    r4000+=1

# %%
r1500,r2000,r3000,r4000

# %%
j=[]
for i in java:
  j.append(i[0])

# %%
p=[]
for i in confirmed:
  p.append(i[0])

# %%
len(set(p))

# %%
len(set(j))

# %%
len(set(p)-set(j))

# %%
list(set(p)-set(j))

# %% [markdown]
# # 2nd Hard Code without 40%

# %%
df_n=pd.read_csv("/content/drive/My Drive/Garvit/Hard Code/New Data.csv")
df_n.tail()

# %%
k=df_n.columns
#print(k)
j=[]
j.extend(k[:4])
j.extend([k[-1]])
j.extend(k[4:-1])

# %%
df_n = df_n[j]

# %%
k=['cust_id', 'Age', 'profession', 'education','cibil_cust_past30_days', 'gender', 'income_source','month_exp', 'marital_status', 'reference_name', 'Name', 'email',
   'phone', 'registration date', 'CreditScore','cibil_age_of_oldest_trade', 'cibil_number_of_open_trades',
   'Severe_status', 'Number_of_Accounts', 'Total_sanction_amount','Total_Past_Due', 'Single_Highest_Credit','Prime Minister Jaan Dhan Yojana - Overdraft','Personal Loan',
   'Overdraft','Other','Kisan Credit Card','Gold Loan','Consumer Loan','Business Loan - Unsecured','Business Loan - Priority Sector- Agriculture','Business Loan']

# %%
a=[]
for j in range(len(df_n.columns)):
  if j<22:
    a.append(df_n.columns[j])
  else:
    indices = [i for i, x in enumerate(df_n.columns[j]) if x == "\'"]
    word=''
    for k in range(indices[2]+1,indices[3]):
      word+=df_n.columns[j][k]
    a.append(word)

# %%
df_test=df_n.drop(columns=k)
all_columns_loan=df_test.sum(axis=1)
a=[]
some_columns_loan=df_test[a]
selected=some_columns_loan.sum(axis=1)
all_columns_loan = all_columns_loan - selected

# %%
credit_card_count = ['Secured Credit Card','Credit Card','Corporate Credit Card']
Two_wheeler_count = ['Two-wheeler Loan']
profession_not_3k=['Auto Driver/Driver','Delivery Agent','Tailor','Laborer/Worker']
confirmed=[]
for index, row in df_n.iterrows():
  if row['CreditScore']>799:
    if row['cibil_age_of_oldest_trade']>35:
      if row['Severe_status'] in ['01+','Non-Delnqt']:
        if row['cibil_cust_past30_days']<2:
          if row.drop(k).sum()>0:
            '''credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
            ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
            if ratio<=0.4:'''
            confirmed.append((row['cust_id'],4000))

    elif row['cibil_age_of_oldest_trade']>23:
      if row['Severe_status'] in ['01+','Non-Delnqt','Std']:
        if row['cibil_cust_past30_days']<3:
          if row.drop(k).sum()>0:
            credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
            '''ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
            if ratio<=0.4:'''
            confirmed.append((row['cust_id'],3000))

    elif row['cibil_age_of_oldest_trade']>11:
      if row['Severe_status'] in ['01+','Non-Delnqt','Std','30+']:
        if row['cibil_cust_past30_days']<4:
          if row.drop(k).sum()>0:
            credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
            '''ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
            if ratio<=0.4:'''
            confirmed.append((row['cust_id'],2000))

  elif row['CreditScore']>779:
    if row['cibil_age_of_oldest_trade']>59:
      if row['Severe_status'] in ['01+','Non-Delnqt','Std']:
        if row['cibil_cust_past30_days']<2:
          if row.drop(k).sum()>0:
            credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
            '''ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
            if ratio<=0.4:'''
            confirmed.append((row['cust_id'],4000))
    
    elif row['cibil_age_of_oldest_trade']>35:
      if row['Severe_status'] in ['01+','Non-Delnqt']:
        if row['cibil_cust_past30_days']<2:
          if row.drop(k).sum()>0:
            credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
            '''ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
            if ratio<=0.4:'''
            confirmed.append((row['cust_id'],3000))

    elif row['cibil_age_of_oldest_trade']>24:
      if row['Severe_status'] in ['01+','Non-Delnqt','Std']:
        if row['cibil_cust_past30_days']<2:
          if row.drop(k).sum()>0:
            credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
            '''ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
            if ratio<=0.4:'''
            confirmed.append((row['cust_id'],2000))
  
  elif row['CreditScore']>769:
    if row['cibil_age_of_oldest_trade']>35:
      if row['Severe_status'] in ['01+','Non-Delnqt']:
        if row['cibil_cust_past30_days']<2:
          if row.drop(k).drop(Two_wheeler_count).sum()>0:
            credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
            '''ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
            if ratio<=0.4:'''
            confirmed.append((row['cust_id'],3000))
    
    elif row['cibil_age_of_oldest_trade']>24:
      if row['Severe_status'] in ['01+','Non-Delnqt','Std']:
        if row['cibil_cust_past30_days']<2:
          if row.drop(k).sum()>0:
            credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
            '''ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
            if ratio<=0.4:'''
            confirmed.append((row['cust_id'],2000))

    elif row['cibil_age_of_oldest_trade']>11:
      if row['Severe_status'] in ['01+','Non-Delnqt','Std','30+','60+']:
        if row['cibil_cust_past30_days']<2:
          if row.drop(k).sum()>0:
            credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
            '''ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
            if ratio<=0.4:'''
            confirmed.append((row['cust_id'],1500))
            
  elif row['CreditScore']>759:
    if row['cibil_age_of_oldest_trade']>35:
      if row['Severe_status'] in ['01+','Non-Delnqt']:
        if row['cibil_cust_past30_days']<2:
          if row.drop(k).drop(Two_wheeler_count).sum()>0:
            credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
            '''ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
            if ratio<=0.4:'''
            confirmed.append((row['cust_id'],3000))

    elif row['cibil_age_of_oldest_trade']>24:
      if row['Severe_status'] in ['01+','Non-Delnqt','Std']:
        if row['cibil_cust_past30_days']<2:
          if row.drop(k).sum()>0:
            credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
            '''ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
            if ratio<=0.4:'''
            confirmed.append((row['cust_id'],2000))

    elif row['cibil_age_of_oldest_trade']>11:
      if row['Severe_status'] in ['01+','Non-Delnqt','Std','30+','60+']:
        if row['cibil_cust_past30_days']<2:
          if row.drop(k).sum()>0:
            credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
            '''ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
            if ratio<=0.4:'''
          confirmed.append((row['cust_id'],1500))
    
  elif row['CreditScore']>749:
    if row['cibil_age_of_oldest_trade']>35:
      if row['profession'] not in profession_not_3k:
        if row['Severe_status'] in ['01+','Non-Delnqt']:
          if row['cibil_cust_past30_days']<2:
            if row.drop(k).drop(Two_wheeler_count).sum()>0:
              credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
              '''ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
              if ratio<=0.4:'''
              confirmed.append((row['cust_id'],3000))
    
    elif row['cibil_age_of_oldest_trade']>24:
      if row['Severe_status'] in ['01+','Non-Delnqt','Std']:
        if row['cibil_cust_past30_days']<2:
          if row.drop(k).sum()>0:
            credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
            '''ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
            if ratio<=0.4:'''
            confirmed.append((row['cust_id'],2000))
      
    elif row['cibil_age_of_oldest_trade']>11:
      if row['Severe_status'] in ['01+','Non-Delnqt','Std','30+','60+']:
        if row['cibil_cust_past30_days']<2:
          if row.drop(k).sum()>0:
            credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
            '''ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
            if ratio<=0.4:'''
            confirmed.append((row['cust_id'],1500))

# %%
df_n.shape

# %%
len(confirmed)

# %%
r1500=0
r2000=0
r3000=0
r4000=0
for i in confirmed:
  if i[1]==1500:
    r1500+=1
  elif i[1]==2000:
    r2000+=1
  elif i[1]==3000:
    r3000+=1
  elif i[1]==4000:
    r4000+=1

# %%
r1500,r2000,r3000,r4000

# %% [markdown]
# # With 40% 1st code

# %%
df_n=pd.read_csv("/content/drive/My Drive/Garvit/Hard Code/New Data.csv")
df_n.tail()

# %%
k=df_n.columns
#print(k)
j=[]
j.extend(k[:4])
j.extend([k[-1]])
j.extend(k[4:-1])

# %%
df_n = df_n[j]

# %%
k=['cust_id', 'Age', 'profession', 'education','cibil_cust_past30_days', 'gender', 'income_source','month_exp', 'marital_status', 'reference_name', 'Name', 'email',
   'phone', 'registration date', 'CreditScore','cibil_age_of_oldest_trade', 'cibil_number_of_open_trades',
   'Severe_status', 'Number_of_Accounts', 'Total_sanction_amount','Total_Past_Due', 'Single_Highest_Credit','Prime Minister Jaan Dhan Yojana - Overdraft','Personal Loan',
   'Overdraft','Other','Kisan Credit Card','Gold Loan','Consumer Loan','Business Loan - Unsecured','Business Loan - Priority Sector- Agriculture','Business Loan']

# %%
a=[]
for j in range(len(df_n.columns)):
  if j<22:
    a.append(df_n.columns[j])
  else:
    indices = [i for i, x in enumerate(df_n.columns[j]) if x == "\'"]
    word=''
    for k in range(indices[2]+1,indices[3]):
      word+=df_n.columns[j][k]
    a.append(word)

# %%
df_test=df_n.drop(columns=k)
all_columns_loan=df_test.sum(axis=1)
a=[]
some_columns_loan=df_test[a]
selected=some_columns_loan.sum(axis=1)
all_columns_loan = all_columns_loan - selected

# %%
credit_card_count = ['Secured Credit Card','Credit Card','Corporate Credit Card']
Two_wheeler_count = ['Two-wheeler Loan']
profession_not_3k=['Auto Driver/Driver','Delivery Agent','Tailor','Laborer/Worker']
confirmed=[]
for index, row in df_n.iterrows():
  if row['CreditScore']>799:
    if row['cibil_age_of_oldest_trade']>35:
      if row['Severe_status'] in ['01+','Non-Delnqt']:
        if row['cibil_cust_past30_days']<2:
          if row.drop(k).sum()>0:
            credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
            ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
            if ratio<=0.4:
              confirmed.append((row['cust_id'],4000))

    elif row['cibil_age_of_oldest_trade']>23:
      if row['Severe_status'] in ['01+','Non-Delnqt','STD']:
        if row['cibil_cust_past30_days']<3:
          if row.drop(k).sum()>0:
            credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
            ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
            if ratio<=0.4:
              confirmed.append((row['cust_id'],3000))

    elif row['cibil_age_of_oldest_trade']>12:
      if row['Severe_status'] in ['01+','Non-Delnqt','STD','30+']:
        if row['cibil_cust_past30_days']<4:
          if row.drop(k).sum()>0:
            credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
            ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
            if ratio<=0.4:
              confirmed.append((row['cust_id'],2000))

  elif row['CreditScore']>779:
    if row['cibil_age_of_oldest_trade']>59:
      if row['Severe_status'] in ['01+','Non-Delnqt','STD']:
        if row['cibil_cust_past30_days']<2:
          if row.drop(k).sum()>0:
            credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
            ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
            if ratio<=0.4:
              confirmed.append((row['cust_id'],4000))
    
    elif row['cibil_age_of_oldest_trade']>35:
      if row['Severe_status'] in ['01+','Non-Delnqt']:
        if row['cibil_cust_past30_days']<2:
          if row.drop(k).sum()>0:
            credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
            ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
            if ratio<=0.4:
              confirmed.append((row['cust_id'],3000))

    elif row['cibil_age_of_oldest_trade']>24:
      if row['Severe_status'] in ['01+','Non-Delnqt','STD']:
        if row['cibil_cust_past30_days']<2:
          if row.drop(k).sum()>0:
            credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
            ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
            if ratio<=0.4:
              confirmed.append((row['cust_id'],2000))
  
  elif row['CreditScore']>769:
    if row['cibil_age_of_oldest_trade']>35:
      if row['Severe_status'] in ['01+','Non-Delnqt']:
        if row['cibil_cust_past30_days']<2:
          if row.drop(k).drop(Two_wheeler_count).sum()>0:
            credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
            ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
            if ratio<=0.4:
              confirmed.append((row['cust_id'],3000))
    
    elif row['cibil_age_of_oldest_trade']>24:
      if row['Severe_status'] in ['01+','Non-Delnqt','STD']:
        if row['cibil_cust_past30_days']<2:
          if row.drop(k).sum()>0:
            credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
            ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
            if ratio<=0.4:
              confirmed.append((row['cust_id'],2000))

    elif row['cibil_age_of_oldest_trade']>12:
      if row['Severe_status'] in ['01+','Non-Delnqt','STD','30+','60+']:
        if row['cibil_cust_past30_days']<2:
          if row.drop(k).sum()>0:
            credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
            ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
            if ratio<=0.4:
              confirmed.append((row['cust_id'],1500))
            
  elif row['CreditScore']>759:
    if row['cibil_age_of_oldest_trade']>35:
      if row['Severe_status'] in ['01+','Non-Delnqt']:
        if row['cibil_cust_past30_days']<2:
          if row.drop(k).drop(Two_wheeler_count).sum()>0:
            credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
            ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
            if ratio<=0.4:
              confirmed.append((row['cust_id'],3000))

    elif row['cibil_age_of_oldest_trade']>24:
      if row['Severe_status'] in ['01+','Non-Delnqt','STD']:
        if row['cibil_cust_past30_days']<2:
          if row.drop(k).sum()>0:
            credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
            ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
            if ratio<=0.4:
              confirmed.append((row['cust_id'],2000))

    elif row['cibil_age_of_oldest_trade']>12:
      if row['Severe_status'] in ['01+','Non-Delnqt','STD','30+','60+']:
        if row['cibil_cust_past30_days']<2:
          if row.drop(k).sum()>0:
            credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
            ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
            if ratio<=0.4:
              confirmed.append((row['cust_id'],1500))
    
  elif row['CreditScore']>749:
    if row['cibil_age_of_oldest_trade']>35:
      if row['profession'] not in profession_not_3k:
        if row['Severe_status'] in ['01+','Non-Delnqt']:
          if row['cibil_cust_past30_days']<2:
            if row.drop(k).drop(Two_wheeler_count).sum()>0:
              credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
              ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
              if ratio<=0.4:
                confirmed.append((row['cust_id'],3000))
    
    elif row['cibil_age_of_oldest_trade']>24:
      if row['Severe_status'] in ['01+','Non-Delnqt','STD']:
        if row['cibil_cust_past30_days']<2:
          if row.drop(k).sum()>0:
            credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
            ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
            if ratio<=0.4:
              confirmed.append((row['cust_id'],2000))
      
    elif row['cibil_age_of_oldest_trade']>11:
      if row['Severe_status'] in ['01+','Non-Delnqt','STD','30+','60+']:
        if row['cibil_cust_past30_days']<2:
          if row.drop(k).sum()>0:
            credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
            ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
            if ratio<=0.4:
              confirmed.append((row['cust_id'],1500))

# %%
df_n.shape

# %%
len(confirmed)

# %%
r1500=0
r2000=0
r3000=0
r4000=0
for i in confirmed:
  if i[1]==1500:
    r1500+=1
  elif i[1]==2000:
    r2000+=1
  elif i[1]==3000:
    r3000+=1
  elif i[1]==4000:
    r4000+=1

# %%
r1500,r2000,r3000,r4000

# %% [markdown]
# # Final

# %%
df_n=pd.read_csv("Downloads/New Data.csv")
#df_n.drop(columns=['Unnamed: 60'],inplace=True)
k=df_n.columns
#print(k)
j=[]
j.extend(k[:4])
j.extend([k[-1]])
j.extend(k[4:-1])

df_n = df_n[j]

a=[]
for j in range(len(df_n.columns)):
  if j<22:
    a.append(df_n.columns[j])
  else:
    indices = [i for i, x in enumerate(df_n.columns[j]) if x == "\'"]
    word=''
    for k in range(indices[2]+1,indices[3]):
      word+=df_n.columns[j][k]
    a.append(word)

df_n.columns=a

df_n.drop_duplicates(inplace=True)

d=[]
for i,row in df_n.iterrows():
  if(row['CreditScore']<550):
    d.append(False)
  else:
    d.append(True)

df_n=df_n[d]

# %%
df_n.head()
# Out:
#    cust_id  Age           profession  education  cibil_cust_past30_days  \
# 0       32   21              Student  Bachelors                       1
# 1       63   30  Government Employee    Masters                       0
# 2     5023   28     Private Employee  Bachelors                       3
# 3     5024   31       Laborer/Worker  Bachelors                       0
# 4     5025   26             Business    Masters                       0
#
#    gender  income_source  month_exp marital_status reference_name  ... Other  \
# 0    Male         Family      10000         Single        Pita Ji  ...   NaN
# 1    Male       Salaried      50000         Single           Papa  ...   NaN
# 2  Female       Salaried      49650        Married           Baba  ...   NaN
# 3    Male  Self Employed      28000        Married     Sweet Home  ...   NaN
# 4    Male  Self Employed      25000         Single        dad new  ...   NaN
#
#   Overdraft  Personal Loan  \
# 0       NaN            NaN
# ...

# %%
k=['cust_id', 'Age', 'profession', 'education','cibil_cust_past30_days', 'gender', 'income_source','month_exp', 'marital_status', 'reference_name', 'Name', 'email',
   'phone', 'registration date', 'CreditScore','cibil_age_of_oldest_trade', 'cibil_number_of_open_trades',
   'Severe_status', 'Number_of_Accounts', 'Total_sanction_amount','Total_Past_Due', 'Single_Highest_Credit','Prime Minister Jaan Dhan Yojana - Overdraft','Personal Loan',
   'Overdraft','Other','Kisan Credit Card','Gold Loan','Consumer Loan','Business Loan - Unsecured','Business Loan - Priority Sector- Agriculture','Business Loan']

# %%
#credit_card_count = ['Secured Credit Card','Credit Card','Corporate Credit Card']
Two_wheeler_count = ['Two-wheeler Loan']
Loan_769_above_24_above=['Auto Loan','Education Loan','Property Loan','Housing Loan', 'Secured Credit Card', 'Loan Against Bank Deposits']
profession_not_3k=['Auto Driver/Driver','Delivery Agent','Tailor','Laborer/Worker']
confirmed=[]
for index, row in df_n.iterrows():
  if row['CreditScore']>799:
    if row['cibil_age_of_oldest_trade']>35:
      if row['Severe_status'] in ['01+','Non-Delnqt']:
        if row['cibil_cust_past30_days']<2:
          if row.drop(k).sum()>0:
            '''credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
            ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
            if ratio<=0.4:'''
            confirmed.append((row['cust_id'],4000))

    elif row['cibil_age_of_oldest_trade']>24:
      if row['Severe_status'] in ['01+','Non-Delnqt','Std']:
        if row['cibil_cust_past30_days']<3:
          if row.drop(k).sum()>0:
            '''credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
            ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
            if ratio<=0.4:'''
            confirmed.append((row['cust_id'],3000))

    elif row['cibil_age_of_oldest_trade']>11:
      if row['Severe_status'] in ['01+','Non-Delnqt','Std','30+']:
        if row['cibil_cust_past30_days']<3:
          if row.drop(k).sum()>0:
            '''credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
            ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
            if ratio<=0.4:'''
            confirmed.append((row['cust_id'],3000))

  elif row['CreditScore']>779:
    if row['cibil_age_of_oldest_trade']>59:
      if row['Severe_status'] in ['01+','Non-Delnqt','Std']:
        if row['cibil_cust_past30_days']<2:
          if row.drop(k).sum()>0:
            '''credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
            ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
            if ratio<=0.4:'''
            confirmed.append((row['cust_id'],4000))
    
    elif row['cibil_age_of_oldest_trade']>35:
      if row['Severe_status'] in ['01+','Non-Delnqt']:
        if row['cibil_cust_past30_days']<2:
          if row.drop(k).sum()>0:
            '''credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
            ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
            if ratio<=0.4:'''
            confirmed.append((row['cust_id'],3000))

    elif row['cibil_age_of_oldest_trade']>24:
      if row['Severe_status'] in ['01+','Non-Delnqt','Std']:
        if row['cibil_cust_past30_days']<2:
          if row[Loan_769_above_24_above].sum()>0:
            '''credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
            ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
            if ratio<=0.4:'''
            confirmed.append((row['cust_id'],3000))
  
  elif row['CreditScore']>769:
    if row['cibil_age_of_oldest_trade']>35:
      if row['Severe_status'] in ['01+','Non-Delnqt','Std']:
        if row['cibil_cust_past30_days']<3:
          if row.drop(k).drop(Two_wheeler_count).sum()>0:
            '''credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
            ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
            if ratio<=0.4:'''
            confirmed.append((row['cust_id'],3000))
    
    elif row['cibil_age_of_oldest_trade']>24:
      if row['Severe_status'] in ['01+','Non-Delnqt','Std']:
        if row['cibil_cust_past30_days']<2:
          if row.drop(k).drop(Two_wheeler_count).sum()>0:
            '''credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
            ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
            if ratio<=0.4:'''
            confirmed.append((row['cust_id'],3000))

    elif row['cibil_age_of_oldest_trade']>11:
      if row['profession'] not in profession_not_3k:
        if row['Severe_status'] in ['01+','Non-Delnqt','Std']:
          if row['cibil_cust_past30_days']<2:
            if row.drop(k).drop(Two_wheeler_count).sum()>0:
              '''credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
              ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
              if ratio<=0.4:'''
              confirmed.append((row['cust_id'],3000))

# %%
cust=[w[0] for w in confirmed]
mask =[]
for i,row in df_n.iterrows():
  if row['cust_id']  in cust:
    mask.append(False)
  else:
    mask.append(True)
df_n=df_n[mask]

# %%
df_n.shape
# Out:
# (7153, 60)

# %%
k=['Auto Loan',
 'Business Loan - Priority Sector- Others',
 'Business Loan - Priority Sector- Small Business',
 'Business Loan - Secured',
 'Business Loan Against Bank Deposits',
 'Business Non-Funded Credit Facility',
 'Business Non-Funded Credit Facility - Priority Sector - Small Business',
 'Commercial Vehicle Loan',
 'Corporate Credit Card',
 'Education Loan',
 'Housing Loan',
 'Loan Against Bank Deposits',
 'Loan against Shares/Securities',
 'Loan to Professional',
 'Property Loan',
 'Secured Credit Card',
 'Tractor Loan',
 'Used Car Loan']

# %%
#credit_card_count = ['Secured Credit Card','Credit Card','Corporate Credit Card']
#Two_wheeler_count = ['Two-wheeler Loan']
profession_not_3k=['Auto Driver/Driver','Delivery Agent','Tailor','Laborer/Worker']
#confirmed=[]
for index, row in df_n.iterrows():
  if row['profession'] not in profession_not_3k:
    if row['CreditScore']>699:
      if row['cibil_age_of_oldest_trade']>11:
        if row['Severe_status'] in ['01+','Non-Delnqt','Std','30+','60+']:
          if row['cibil_cust_past30_days']<3:
            if row[k].sum()>0:
              '''credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
              ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
              if ratio<=0.4:'''
              confirmed.append((row['cust_id'],3000))

# %%
k=['Auto Loan',
 'Corporate Credit Card',
 'Education Loan',
 'Housing Loan',
 'Secured Credit Card',
 'Used Car Loan']

# %%
#credit_card_count = ['Secured Credit Card','Credit Card','Corporate Credit Card']
#Two_wheeler_count = ['Two-wheeler Loan']
profession_not_3k=['Auto Driver/Driver','Delivery Agent','Tailor','Laborer/Worker']
#confirmed=[]
for index, row in df_n.iterrows():
  if row['profession'] not in profession_not_3k:
    if 700>row['CreditScore']>550:
      if row['cibil_age_of_oldest_trade']>23:
        if row['Severe_status'] in ['01+','Non-Delnqt']:
          if row['cibil_cust_past30_days']<3:
            if row[k].sum()>0:
              '''credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
              ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
              if ratio<=0.4:'''
              confirmed.append((row['cust_id'],2000))

# %%
r1500=0
r2000=0
r3000=0
r4000=0
for i in confirmed:
  if i[1]==1500:
    r1500+=1
  elif i[1]==2000:
    r2000+=1
  elif i[1]==3000:
    r3000+=1
  elif i[1]==4000:
    r4000+=1

# %%
r1500,r2000,r3000,r4000
# Out:
# (0, 104, 346, 5)

# %%
len(confirmed)
# Out:
# 455

# %%
l_increase_3k=[]
for i in list(set(confirmed)):
  if(i[1]==3000):
    l_increase_3k.append(i[0])

# %%
with open('Downloads/Limit_Increase_Users_3k.txt', 'w') as f:
    for item in l_increase_3k:
        f.write(str(item))
        f.write('\n')

# %%
l_increase_4k=[]
for i in list(set(confirmed)):
  if(i[1]==4000):
    l_increase_4k.append(i[0])

# %%
with open('Downloads/Limit_Increase_Users_4k.txt', 'w') as f:
    for item in l_increase_4k:
        f.write(str(item))
        f.write('\n')

# %%
confirmed

# %%
set(confirmed)
# Out:
# {(5147, 3000),
#  (5269, 3000),
#  (5288, 3000),
#  (5379, 2000),
#  (5489, 3000),
#  (5504, 3000),
#  (5691, 3000),
#  (6268, 3000),
#  (6408, 3000),
#  (6677, 3000),
#  (7103, 3000),
#  (7463, 3000),
#  (7586, 3000),
#  (7925, 2000),
#  (7996, 3000),
#  (8210, 3000),
#  (8226, 3000),
#  (8271, 2000),
#  (8425, 2000),
#  (8933, 2000),
#  (9609, 3000),
#  (9916, 3000),
#  (9920, 3000),
#  (10205, 3000),
#  (10374, 3000),
#  (10573, 3000),
#  (11184, 3000),
#  (11233, 3000),
#  (11580, 3000),
#  (11626, 3000),
#  (12095, 3000),
#  (12405, 3000),
#  (12771, 3000),
#  (12948, 2000),
#  (13011, 3000),
#  (13153, 3000),
#  (13161, 3000),
#  (13172, 3000),
#  (13381, 3000),
#  (13438, 3000),
#  (13884, 3000),
#  (13944, 3000),
#  (14144, 3000),
#  (14598, 2000),
#  (14645, 3000),
#  (14804, 3000),
#  (14913, 3000),
#  (14996, 3000),
#  (15356, 2000),
#  (16307, 3000),
#  (16570, 4000),
#  (16851, 2000),
#  (17533, 3000),
#  (17558, 2000),
#  (17758, 3000),
#  (17787, 2000),
# ...

# %%
len(confirmed)

# %%
g=[]
for i in confirmed:
  if(i[0]==145631):
      print(i)
g.sort()

# %%
for i in range(len(g)-1):
  if(g[i]==g[i+1]):
    print(g[i])

# %% [markdown]
# # For the 1st time loans

# %%
def Loan_first(row):
  k=['Auto Loan',
  'Corporate Credit Card',
  'Education Loan',
  'Housing Loan',
  'Secured Credit Card',
  'Used Car Loan']
  #credit_card_count = ['Secured Credit Card','Credit Card','Corporate Credit Card']
  #Two_wheeler_count = ['Two-wheeler Loan']
  profession_not_3k=['Auto Driver/Driver','Delivery Agent','Tailor','Laborer/Worker']
  #confirmed=[]
  if row['profession'] not in profession_not_3k:
    if 700>row['CreditScore']>550:
      if row['cibil_age_of_oldest_trade']>23:
        if row['Severe_status'] in ['01+','Non-Delnqt']:
          if row['cibil_cust_past30_days']<3:
            if row[k].sum()>0:
              '''credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
              ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
              if ratio<=0.4:'''
              return 2000
  else:
    return 0

# %% [markdown]
# # For Limit increase

# %%
def limit_increase(row):
  k=['cust_id', 'Age', 'profession', 'education','cibil_cust_past30_days', 'gender', 'income_source','month_exp', 'marital_status', 'reference_name', 'Name', 'email',
    'phone', 'registration date', 'CreditScore','cibil_age_of_oldest_trade', 'cibil_number_of_open_trades',
    'Severe_status', 'Number_of_Accounts', 'Total_sanction_amount','Total_Past_Due', 'Single_Highest_Credit','Prime Minister Jaan Dhan Yojana - Overdraft','Personal Loan',
    'Overdraft','Other','Kisan Credit Card','Gold Loan','Consumer Loan','Business Loan - Unsecured','Business Loan - Priority Sector- Agriculture','Business Loan']
  #credit_card_count = ['Secured Credit Card','Credit Card','Corporate Credit Card']
  Two_wheeler_count = ['Two-wheeler Loan']
  Loan_769_above_24_above=['Auto Loan','Education Loan','Property Loan','Housing Loan', 'Secured Credit Card', 'Loan Against Bank Deposits']
  profession_not_3k=['Auto Driver/Driver','Delivery Agent','Tailor','Laborer/Worker']

  if row['CreditScore']>799:
    if row['cibil_age_of_oldest_trade']>35:
      if row['Severe_status'] in ['01+','Non-Delnqt']:
        if row['cibil_cust_past30_days']<2:
          if row.drop(k).sum()>0:
            '''credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
            ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
            if ratio<=0.4:'''
            return 4000

    elif row['cibil_age_of_oldest_trade']>24:
      if row['Severe_status'] in ['01+','Non-Delnqt','Std']:
        if row['cibil_cust_past30_days']<3:
          if row.drop(k).sum()>0:
            '''credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
            ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
            if ratio<=0.4:'''
            return 3000

    elif row['cibil_age_of_oldest_trade']>11:
      if row['Severe_status'] in ['01+','Non-Delnqt','Std','30+']:
        if row['cibil_cust_past30_days']<3:
          if row.drop(k).sum()>0:
            '''credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
            ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
            if ratio<=0.4:'''
            return 3000

  elif row['CreditScore']>779:
    if row['cibil_age_of_oldest_trade']>59:
      if row['Severe_status'] in ['01+','Non-Delnqt','Std']:
        if row['cibil_cust_past30_days']<2:
          if row.drop(k).sum()>0:
            '''credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
            ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
            if ratio<=0.4:'''
            return 4000
    
    elif row['cibil_age_of_oldest_trade']>35:
      if row['Severe_status'] in ['01+','Non-Delnqt']:
        if row['cibil_cust_past30_days']<2:
          if row.drop(k).sum()>0:
            '''credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
            ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
            if ratio<=0.4:'''
            return 3000

    elif row['cibil_age_of_oldest_trade']>24:
      if row['Severe_status'] in ['01+','Non-Delnqt','Std']:
        if row['cibil_cust_past30_days']<2:
          if row[Loan_769_above_24_above].sum()>0:
            '''credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
            ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
            if ratio<=0.4:'''
            return 3000

  elif row['CreditScore']>769:
    if row['cibil_age_of_oldest_trade']>35:
      if row['Severe_status'] in ['01+','Non-Delnqt','Std']:
        if row['cibil_cust_past30_days']<3:
          if row.drop(k).drop(Two_wheeler_count).sum()>0:
            '''credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
            ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
            if ratio<=0.4:'''
            return 3000
    
    elif row['cibil_age_of_oldest_trade']>24:
      if row['Severe_status'] in ['01+','Non-Delnqt','Std']:
        if row['cibil_cust_past30_days']<2:
          if row.drop(k).drop(Two_wheeler_count).sum()>0:
            '''credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
            ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
            if ratio<=0.4:'''
            return 3000

    elif row['cibil_age_of_oldest_trade']>11:
      if row['profession'] not in profession_not_3k:
        if row['Severe_status'] in ['01+','Non-Delnqt','Std']:
          if row['cibil_cust_past30_days']<2:
            if row.drop(k).drop(Two_wheeler_count).sum()>0:
              '''credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
              ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
              if ratio<=0.4:'''
              return 3000
  else:
    k=['Auto Loan',
    'Business Loan - Priority Sector- Others',
    'Business Loan - Priority Sector- Small Business',
    'Business Loan - Secured',
    'Business Loan Against Bank Deposits',
    'Business Non-Funded Credit Facility',
    'Business Non-Funded Credit Facility - Priority Sector - Small Business',
    'Commercial Vehicle Loan',
    'Corporate Credit Card',
    'Education Loan',
    'Housing Loan',
    'Loan Against Bank Deposits',
    'Loan against Shares/Securities',
    'Loan to Professional',
    'Property Loan',
    'Secured Credit Card',
    'Tractor Loan',
    'Used Car Loan']
    #credit_card_count = ['Secured Credit Card','Credit Card','Corporate Credit Card']
    #Two_wheeler_count = ['Two-wheeler Loan']
    profession_not_3k=['Auto Driver/Driver','Delivery Agent','Tailor','Laborer/Worker']
    #confirmed=[]
    if row['profession'] not in profession_not_3k:
      if row['CreditScore']>699:
        if row['cibil_age_of_oldest_trade']>11:
          if row['Severe_status'] in ['01+','Non-Delnqt','Std','30+','60+']:
            if row['cibil_cust_past30_days']<3:
              if row[k].sum()>0:
                '''credit_cart_total=1 if row[credit_card_count].sum()>0 else 0
                ratio = (row['cibil_number_of_open_trades']-row[credit_card_count].sum()+credit_cart_total)/row['Number_of_Accounts']
                if ratio<=0.4:'''
                return 3000
  return 0

# %% [markdown]
# # New Civil

# %%
df=pd.read_csv('Downloads/cibildata.csv')
df.head()
# Out:
#    user_id  account_type  ac_status  r_o_i  income_account  repay_tenure  \
# 0   179908             5         80    NaN             NaN             0
# 1   179908             5         80    NaN             NaN             0
# 2   179908             5         13    NaN             NaN             0
# 3   179908             5         13    NaN             NaN             0
# 4   179908             6         12    NaN             NaN             0
#
#   payment_rating                   pay_history-profile  original_loanamount  \
# 0              3  11??????????????????????????????????               1000.0
# 1              3  2100????????????????????????????????               2200.0
# 2              0  0???????????????????????????????????               1600.0
# 3              0                                     N               2200.0
# 4              ?                                     N                500.0
#
# ...

# %%
df['user_id'].unique()
# Out:
# array([179908, 178472, 184122, 183293, 182548, 173335, 174166, 171241,
#        172042, 180845, 176968, 175333, 180848, 175761, 181714, 176509,
#        174283, 181584, 180152, 178014, 179690, 176487, 181008, 183512,
#        171112, 183463, 174994, 178462, 183796, 175444, 180231, 171233,
#        183614, 182142, 181918, 184139, 170593, 184172, 175525, 181204,
#        170399, 178297, 171670, 173190, 180770, 173968, 182451, 178985,
#        172619, 182896, 179545, 171587, 177416, 172074, 184615, 177756,
#        181925, 181611, 175061, 181733, 174066, 179954, 183047, 170366,
#        172501, 170057, 179129, 184396, 171814, 172770, 176379, 183182,
#        173590, 174932, 174154, 171749, 181494, 173143, 181861, 177242,
#        176219, 171155, 172561, 179930, 181354, 182003, 177612, 171696,
#        176682, 183671, 181502, 170257, 181704, 179305, 177789, 179073,
#        176143, 179237, 183089, 178552, 183279, 176549, 180079, 176162,
# ...

# %%
df.shape
# Out:
# (3513, 24)

# %%
df_new={}
for i in list(df['user_id'].unique()):
  df_new[i]={'loan':0,'history':'N','score':0,'amt_principal':0,'amt_total':0}
df_new.keys()
# Out:
# dict_keys([179908, 178472, 184122, 183293, 182548, 173335, 174166, 171241, 172042, 180845, 176968, 175333, 180848, 175761, 181714, 176509, 174283, 181584, 180152, 178014, 179690, 176487, 181008, 183512, 171112, 183463, 174994, 178462, 183796, 175444, 180231, 171233, 183614, 182142, 181918, 184139, 170593, 184172, 175525, 181204, 170399, 178297, 171670, 173190, 180770, 173968, 182451, 178985, 172619, 182896, 179545, 171587, 177416, 172074, 184615, 177756, 181925, 181611, 175061, 181733, 174066, 179954, 183047, 170366, 172501, 170057, 179129, 184396, 171814, 172770, 176379, 183182, 173590, 174932, 174154, 171749, 181494, 173143, 181861, 177242, 176219, 171155, 172561, 179930, 181354, 182003, 177612, 171696, 176682, 183671, 181502, 170257, 181704, 179305, 177789, 179073, 176143, 179237, 183089, 178552, 183279, 176549, 180079, 176162, 176171, 181332, 170815, 180223, 172820, 180070, 178802, 178735, 170765, 180129, 175736, 180250, 170596, 181104, 171623, 180503, 182756, 174073, 175905, 178
# ...

# %%
x = df[df['user_id'] == 181726]
x
# Out:
#       user_id  account_type  ac_status  r_o_i  income_account  repay_tenure  \
# 2615   181726            10         33    NaN             NaN             0
# 2616   181726             3         11    NaN             NaN           120
# 2617   181726             2         11    NaN             NaN           240
# 2618   181726             6         11    NaN             NaN             0
#
#      payment_rating                   pay_history-profile  \
# 2615              0  055555555555555555555555555555555555
# 2616              0  000000000000000000000000000000000000
# 2617              0  000?00000000000000000000000000000000
# 2618              0                                     N
#
#       original_loanamount  written_of_settled_status  ...  caps_last90days  \
# 2615              82438.0                        4.0  ...               13
# 2616             100000.0                        NaN  ...               13
# ...

# %%
loan=[1,2,3,8,15]
unneeded_history=['S','D','B','6','5','4','3','?','L','M']
for i,row in df.iterrows():  
  #if row['user_id']!=181726:
  #  continue
  #print(6)
  if row['account_type'] in loan:
    df_new[row['user_id']]['loan']+=1

  s2,s1,s0,sn,ss,sd,sb,s3,s4,s5,s6,sl,sm=False,False,False,False,False,False,False,False,False,False,False,False,False
  # print(df_new[row['user_id']]['history'])break
  #print(df_new[row['user_id']]['history'])
  if df_new[row['user_id']]['history'] not in unneeded_history:
    #print(row['pay_history-profile'])
    #print(type(row['pay_history-profile']))
    for i in row['pay_history-profile']:
      if i=='S':
        ss=True
        break
      elif i=='B':
        sb=True
        break
      elif i=='D':
        sd=True
        break
      elif i=='L':
        sl=True
        break
      elif i=='M':
        sm=True
        break
      elif i=='6':
        s6=True
        break
      elif i=='5':
        #print(5)
        s5=True
        break
      elif i=='4':
        s4=True
        break
      elif i=='3':
        s3=True
        break
      elif i=='2':
        s2=True
      elif i=='1':
        s1=True
      elif i=='0':
        #print(0)
        s0=True
      elif i=='N':
        sn=True
    if ss:
      df_new[row['user_id']]['history']='S'
    elif sd:
      df_new[row['user_id']]['history']='D'
    elif sb:
      df_new[row['user_id']]['history']='B'
    elif s6:
      df_new[row['user_id']]['history']='6'
    elif sl:
      df_new[row['user_id']]['history']='L'
    elif sm:
      df_new[row['user_id']]['history']='M'
    elif s5:
      df_new[row['user_id']]['history']='5'
    elif s4:
      df_new[row['user_id']]['history']='4'
    elif s3:
      df_new[row['user_id']]['history']='3'
    elif s2:
      df_new[row['user_id']]['history']='2'
    elif s1:
      df_new[row['user_id']]['history']='1'
    elif s0:
      df_new[row['user_id']]['history']='0'
    elif sn:
      df_new[row['user_id']]['history']='N'

    df_new[row['user_id']]['score']=row['credit_score']
    if row['written-of-amt-total'] != 0 and not np.isnan(row['written-of-amt-total']):
      df_new[row['user_id']]['amt_total'] = row['written-of-amt-total']
    if row['written-amt_principal'] != 0 and not np.isnan(row['written-amt_principal']):
      df_new[row['user_id']]['amt_principal'] = row['written-amt_principal']

# %%
a=df['written-of-amt-total'][1]
not np.isnan(a)
# Out:
# True

# %%
a==0
# Out:
# True

# %%
type(a)
# Out:
# numpy.float64

# %%
b=np.nan
a==0
# Out:
# True

# %%
df_new[181726]
# Out:
# {'loan': 2, 'history': '5', 'score': 786, 'amt_principal': 0, 'amt_total': 0}

# %%
first_list=[]
second_list=[]
selected=['N','0','1','2']
for i in df_new.keys():
  if df_new[i]['score']>749:
    if df_new[i]['loan']>0:
      if df_new[i]['history'] in selected:
        if df_new[i]['amt_total']==0 or np.isnan(df_new[i]['amt_total']):
          first_list.append(i)
  
  elif df_new[i]['score']>649:
    if df_new[i]['loan']>0:
      if df_new[i]['history'] in selected:
        if df_new[i]['amt_total']==0 or np.isnan(df_new[i]['amt_total']):
          second_list.append(i)

# %%
'?' not in unneeded_history
# Out:
# False

# %%
len(first_list)
# Out:
# 8

# %%
len(second_list)
# Out:
# 10

# %%
first_list
# Out:
# [179129, 181502, 172820, 180130, 182110, 181294, 180266, 181100]

# %%
second_list
# Out:
# [170399,
#  178985,
#  178735,
#  175905,
#  170224,
#  178446,
#  182421,
#  172828,
#  176749,
#  181261]

# %%
l=[]
for i in range(df.shape[0]):
  for j in df['pay_history-profile'][i]:
    l.append(j)

# %%
set(l)
# Out:
# {'0', '1', '2', '3', '4', '5', '6', '?', 'B', 'D', 'L', 'M', 'N', 'S'}
